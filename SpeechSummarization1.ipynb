# %% [markdown]
# <a href="https://colab.research.google.com/github/ZahraArshia/Speech-Summarization/blob/master/SpeechSummarization1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #install nessecery packages

# %%
# !pip install subprocess.run
# !pip install gTTS
# !pip install ipython
# !pip install vosk
# !pip install pydub
# !pip install torchmetrics

# %%
# !pip install transformers
# !pip install regex
# !pip install torch

# %% [markdown]
# #Libreries

# %%
import requests
import json
from time import sleep
from gtts import gTTS
import IPython
import sys

from torchmetrics.functional.text.rouge import rouge_score

from vosk import Model, KaldiRecognizer
import subprocess

# %% [markdown]
# #**MODEL**

# %%
FRAME_RATE = 16000
CHANNELS = 1

#load model
model = Model(model_name= "vosk-model-en-us-0.22")

#initialize recognizer
rec = KaldiRecognizer(model ,FRAME_RATE)

#show text transcript and individual words and the models confidence on the other hand give us information about that
rec.SetWords(True)

# %%
#load audio file to pass the recognizer model and for this work we use pydub library
from pydub import AudioSegment #this is a class that enable us to load audio and Manipulate it

# %%
#load the file
path = "/content/drive/MyDrive/data/Bdb001.interaction.wav"
speech = AudioSegment.from_file(path)
#set the number of channel of audio
speech = speech.set_channels(CHANNELS)
#set frame number of audio
speech = speech.set_frame_rate(FRAME_RATE)

# %%
#pass audio file into speech recognition model
rec.AcceptWaveform(speech.raw_data)  #raw_data is a bi nary representation of the actual data

#result of speech recognition
result = rec.Result()  #it returns json file format

# %%
text = json.loads(result)["text"]  #this can convert it to a python dictionary

# %%
text

# %%
json.loads(result)

# %%
cased = subprocess.check_output("", shell=True, text=True, input=text)

# %% [markdown]
# #A function to trancribe longer audio

# %%
def voice_recognition():
  #load model
  model = Model(model_name= "vosk-model-en-us-0.22")

  #initialize recognizer
  rec = KaldiRecognizer(model ,FRAME_RATE)

  #show text transcript and individual words and the models confidence on the other hand give us information about that
  rec.SetWords(True)

  #load the file
  speech = AudioSegment.from_file(path)
  #set the number of channel of audio
  speech = speech.set_channels(CHANNELS)
  #set frame number of audio
  speech = speech.set_frame_rate(FRAME_RATE)

  step = 45000
  transcript = ""
  for i for range(0, len(speech), step):
    print(f"progress: {i/len(speech)}")
    segment = speech[i:(i+step)]

    #pass audio file into speech recognition model
    rec.AcceptWaveform(speech.raw_data)  #raw_data is a bi nary representation of the actual data

    #result of speech recognition
    result = rec.Result()  #it returns json file format

    text = json.loads(result)["text"]
    transcript += text

cased =
return cased

# %% [markdown]
# #summerization

# %%
from transformers import pipeline
summ = pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
split_tokens = transcript.split("")
docs = []
for i range(0 , len(split_tokens), 850):
  selection =" ".join(split_tokens[i:(i+850)])
  docs.append(selection)
